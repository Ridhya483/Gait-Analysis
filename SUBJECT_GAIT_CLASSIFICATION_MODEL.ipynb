# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train = pd.read_csv('train.csv')

# %%
train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
train['subject'].unique()
# Out:
# array([ 1,  3,  5,  6,  7,  8, 11, 14, 15, 16, 17, 19, 21, 22, 23, 25, 26,
#        27, 28, 29, 30], dtype=int64)

# %%
sub_count = train.groupby('subject')['subject'].count()

# %%
y = []
for i in sub_count :
    y.append(i)

# %%
y
# Out:
# [347,
#  341,
#  302,
#  325,
#  308,
#  281,
#  316,
#  323,
#  328,
#  366,
#  368,
#  360,
#  408,
#  321,
#  372,
#  409,
#  392,
#  376,
#  382,
#  344,
#  383]

# %%
x_lab = train['subject'].unique()

# %%
x_lab
# Out:
# array([ 1,  3,  5,  6,  7,  8, 11, 14, 15, 16, 17, 19, 21, 22, 23, 25, 26,
#        27, 28, 29, 30], dtype=int64)

# %%
x = []

for i in x_lab:
    x.append(str(i))

# %%
x
# Out:
# ['1',
#  '3',
#  '5',
#  '6',
#  '7',
#  '8',
#  '11',
#  '14',
#  '15',
#  '16',
#  '17',
#  '19',
#  '21',
#  '22',
#  '23',
#  '25',
#  '26',
#  '27',
#  '28',
#  '29',
#  '30']

# %%
fig = plt.figure(figsize=(20,5))
plt.bar(x, y)
# Out:
# <BarContainer object of 21 artists>

# %%
# subjects 21 and 25 have the highest number of data rows so we will work on their data

# %%
sub21 = train[train['subject'] == 21]

# %%
sub21  #sensor data of only subject 21
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 3965           0.245350          -0.025551          -0.233971
# 3966           0.319396          -0.009461          -0.134561
# 3967           0.280378          -0.009429          -0.078623
# 3968           0.277186          -0.021057          -0.088045
# 3969           0.285473          -0.024408          -0.086753
# ...                 ...                ...                ...
# 4368           0.250338          -0.007885          -0.150313
# 4369           0.257712          -0.018160          -0.204960
# 4370           0.281083          -0.029388          -0.168461
# 4371           0.238773           0.004982          -0.048661
# 4372           0.405870          -0.022017          -0.047245
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 3965         -0.847169         -0.805181         -0.717554         -0.893054
# ...

# %%
sub21.groupby('Activity')['Activity'].count()
# Out:
# Activity
# LAYING                90
# SITTING               85
# STANDING              89
# WALKING               52
# WALKING_DOWNSTAIRS    45
# WALKING_UPSTAIRS      47
# Name: Activity, dtype: int64

# %%
sub25 = train[train['subject'] == 25]

# %%
sub25  #sensor data of subject 25
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 5066           0.304858          -0.020152          -0.106627
# 5067           0.288476          -0.018694          -0.116258
# 5068           0.274164          -0.016013          -0.112990
# 5069           0.276513          -0.015279          -0.103881
# 5070           0.277716          -0.016574          -0.101086
# ...                 ...                ...                ...
# 5470           0.304153          -0.087978          -0.119198
# 5471           0.328337          -0.006552          -0.058159
# 5472           0.258026           0.030093          -0.087266
# 5473           0.202443          -0.027988          -0.208068
# 5474           0.310518          -0.029823          -0.183774
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 5066         -0.963456         -0.941173         -0.962273         -0.974110
# ...

# %%
sub25.groupby('Activity')['Activity'].count()
# Out:
# Activity
# LAYING                73
# SITTING               65
# STANDING              74
# WALKING               74
# WALKING_DOWNSTAIRS    58
# WALKING_UPSTAIRS      65
# Name: Activity, dtype: int64

# %%
# removing activity column as it will not be required in classification

# %%
sub21.drop(columns = 'Activity' , inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
sub25.drop(columns = 'Activity' , inplace = True)

# %%
sub21
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 3965           0.245350          -0.025551          -0.233971
# 3966           0.319396          -0.009461          -0.134561
# 3967           0.280378          -0.009429          -0.078623
# 3968           0.277186          -0.021057          -0.088045
# 3969           0.285473          -0.024408          -0.086753
# ...                 ...                ...                ...
# 4368           0.250338          -0.007885          -0.150313
# 4369           0.257712          -0.018160          -0.204960
# 4370           0.281083          -0.029388          -0.168461
# 4371           0.238773           0.004982          -0.048661
# 4372           0.405870          -0.022017          -0.047245
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 3965         -0.847169         -0.805181         -0.717554         -0.893054
# ...

# %%
sub25
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
#
# Out:
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 794           0.294400          -0.002797          -0.055839
# 569           0.206489          -0.041815          -0.100073
# 148           0.298077           0.022145          -0.092031
# 68            0.291895           0.001381          -0.131790
# 62            0.276472          -0.014828          -0.108358
# ..                 ...                ...                ...
# 255           0.229336          -0.022803          -0.176032
# 72            0.277094          -0.015745          -0.100308
# 300           0.307327          -0.012284          -0.119300
# 500           0.273276          -0.015712          -0.106581
# 491          -0.466440          -0.618098           0.948795
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 794         -0.432460         -0.231223         -0.193114         -0.491268
# 569         -0.346680         -0.166435         -0.459004         -0.371154
# ...

# %%
test
# Out:
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 475           0.276829          -0.016250          -0.108938
# 476           0.279363          -0.015436          -0.110706
# 92            0.071000          -0.042099           0.082334
# 270           0.275991          -0.014417          -0.109283
# 550           0.271285          -0.018346          -0.112656
# ..                 ...                ...                ...
# 718           0.270059           0.022795          -0.175338
# 664           0.278450          -0.013940          -0.096580
# 561           0.294790          -0.000700          -0.124621
# 431           0.286141          -0.014982          -0.118960
# 736           0.279181           0.008722          -0.114867
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 475         -0.995769         -0.992582         -0.990050         -0.995969
# 476         -0.995078         -0.993078         -0.989486         -0.995140
# ...

# %%
X_train=train.iloc[:,:-1]
y_train=train.iloc[:,-1]

X_test=test.iloc[:,:-1]
y_test=test.iloc[:,-1]

# %%
X_train
# Out:
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 794           0.294400          -0.002797          -0.055839
# 569           0.206489          -0.041815          -0.100073
# 148           0.298077           0.022145          -0.092031
# 68            0.291895           0.001381          -0.131790
# 62            0.276472          -0.014828          -0.108358
# ..                 ...                ...                ...
# 255           0.229336          -0.022803          -0.176032
# 72            0.277094          -0.015745          -0.100308
# 300           0.307327          -0.012284          -0.119300
# 500           0.273276          -0.015712          -0.106581
# 491          -0.466440          -0.618098           0.948795
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 794         -0.432460         -0.231223         -0.193114         -0.491268
# 569         -0.346680         -0.166435         -0.459004         -0.371154
# ...

# %%
y_train
# Out:
# 794    1
# 569    1
# 148    0
# 68     0
# 62     0
#       ..
# 255    0
# 72     0
# 300    0
# 500    1
# 491    1
# Name: subject, Length: 572, dtype: int64

# %%
X_test
# Out:
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 475           0.276829          -0.016250          -0.108938
# 476           0.279363          -0.015436          -0.110706
# 92            0.071000          -0.042099           0.082334
# 270           0.275991          -0.014417          -0.109283
# 550           0.271285          -0.018346          -0.112656
# ..                 ...                ...                ...
# 718           0.270059           0.022795          -0.175338
# 664           0.278450          -0.013940          -0.096580
# 561           0.294790          -0.000700          -0.124621
# 431           0.286141          -0.014982          -0.118960
# 736           0.279181           0.008722          -0.114867
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 475         -0.995769         -0.992582         -0.990050         -0.995969
# 476         -0.995078         -0.993078         -0.989486         -0.995140
# ...

# %%
y_test
# Out:
# 475    1
# 476    1
# 92     0
# 270    0
# 550    1
#       ..
# 718    1
# 664    1
# 561    1
# 431    1
# 736    1
# Name: subject, Length: 245, dtype: int64

# %%
X_train.to_csv('X_train.csv' , index = False)
y_train.to_csv('y_train.csv' , index = False)
X_test.to_csv('X_test.csv' , index = False)
y_test.to_csv('y_test.csv' , index = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   after removing the cwd from sys.path.

# %% [markdown]
# # Sequential Model [ feed forward NN ]

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout

# %%
model=Sequential()

model.add(Dense(units=64,kernel_initializer='he_uniform',activation='relu',input_dim=X_train.shape[1]))

model.add(Dense(units=128,kernel_initializer='he_uniform',activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(units=128,kernel_initializer='he_uniform',activation='relu'))

model.add(Dense(units=64,kernel_initializer='he_uniform',activation='relu'))

model.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_35 (Dense)             (None, 64)                35968
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_39 (Dense)             (None, 1)                 65
# ...
# Total params: 69,121
# Trainable params: 69,121
# Non-trainable params: 0
# ...

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,batch_size=256,epochs=50,validation_data=(X_test,y_test))
# Out:
# Train on 572 samples, validate on 245 samples
# Epoch 1/50
# 572/572 [==============================] - 1s 1ms/step - loss: 1.1395 - accuracy: 0.4843 - val_loss: 0.8096 - val_accuracy: 0.5020
# Epoch 2/50
# 572/572 [==============================] - 0s 107us/step - loss: 0.7916 - accuracy: 0.5017 - val_loss: 0.6927 - val_accuracy: 0.5755
# Epoch 3/50
# 572/572 [==============================] - 0s 77us/step - loss: 0.7065 - accuracy: 0.5420 - val_loss: 0.6728 - val_accuracy: 0.5592
# Epoch 4/50
# 572/572 [==============================] - 0s 77us/step - loss: 0.6908 - accuracy: 0.5752 - val_loss: 0.6449 - val_accuracy: 0.7429
# Epoch 5/50
# 572/572 [==============================] - 0s 84us/step - loss: 0.6509 - accuracy: 0.6434 - val_loss: 0.6169 - val_accuracy: 0.6612
# Epoch 6/50
# 572/572 [==============================] - 0s 77us/step - loss: 0.6269 - accuracy: 0.6329 - val_loss: 0.5744 - val_accuracy: 0.7265
# Epoch 7/50
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree

# %%
clf_mdl_gini = tree.DecisionTreeClassifier()   # using gini impurity and best split [as they are default]

# %%
clf_mdl_gini = clf_mdl_gini.fit(X_train , y_train)

# %%
from sklearn import metrics
def measure_performance(X_test,y_test, clf_mdl, show_accuracy=True , show_confusion_matrix = True):
    y_pred=clf_mdl.predict(X_test)   
    if show_accuracy:
        print ("Accuracy:{0:.3f}".format(metrics.accuracy_score(y_test,y_pred)),"\n")
    
    
        
    if show_confusion_matrix:
        print ("Confusion matrix")
        print (metrics.confusion_matrix(y_test,y_pred),"\n")

# %%
measure_performance(X_test , y_test , clf_mdl_gini)
# Out:
# Accuracy:0.996
#
# Confusion matrix
# [[132   0]
#  [  1 112]]

# %%
clf_mdl_gini.tree_.max_depth   # max depth of the gini decision tree
# Out:
# 5

# %%
# a decision tree using entropy as crieteria for building a decision tree

# %%
clf_mdl_ent = tree.DecisionTreeClassifier(criterion = "entropy")

# %%
clf_mdl_ent = clf_mdl_ent.fit(X_train,y_train)

# %%
measure_performance(X_test , y_test , clf_mdl_ent)
# Out:
# Accuracy:0.996
#
# Confusion matrix
# [[131   1]
#  [  0 113]]

# %%
clf_mdl_ent.tree_.max_depth   # max depth of entropy decision tree
# Out:
# 5

# %%
# both the methods [ gini and entropy give almost the same accuracy ]

# %%
# the training dataset has only 572 samples
# this is quite less as compared to a normal classification dataset
# a high accuracy is achieved despite a small dataset is because of the large number of features [ columns ] for each sample
# the model can be improved upon by expanding the dataset

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rdm_forest_gini = RandomForestClassifier(n_estimators = 100)

# %%
rdm_forest_gini.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
measure_performance(X_test , y_test , rdm_forest_gini)
# Out:
# Accuracy:0.992
#
# Confusion matrix
# [[131   1]
#  [  1 112]]

# %%
# this was a RandomForestClassifier with 100 trees [ n_estimators ] with gini criterion

# %%
rdm_forest_ent = RandomForestClassifier(n_estimators = 100 , criterion = 'entropy')

# %%
rdm_forest_ent.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
measure_performance(X_test , y_test , rdm_forest_ent)
# Out:
# Accuracy:0.992
#
# Confusion matrix
# [[130   2]
#  [  0 113]]

# %%
# even in the case of RandomForestClassifier both gini and entropy models gave almost the same accuracy 
# again there might be some level of overfitting present which can be resolved by expanding the dataset
